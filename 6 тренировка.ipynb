# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, k = list(map(int, input().split()))

mas_n = list(map(int, input().split()))
mas_m = list(map(int, input().split()))

for one in mas_m:
    num = one
    l = 0
    r = n
    if mas_n[n -1] >= num:
        if num < mas_n[0]:
            print("NO")
        else:
            while l < r:
                m = (l + r) //  2
                if mas_n[m] >= num:
                    r = m
                else:
                    l = m + 1
            #print(mas_n[l], num)      
            print("YES" if mas_n[l] == num else "NO")
    else:
        print("NO")
# Out:
# 10 10
# -8 -6 -4 -4 -2 -1 0 2 3 3
# 8 3 -3 -2 2 -1 2 9 -8 0
# No
# YES
# NO
# YES
# YES
# YES
# YES
# No
# YES
# YES

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys 
n, k = list(map(int, input().split()))

mas_n = list(map(int, sys.stdin.read().split()))
mas_m = list(map(int, sys.stdin.read().split()))

for one in mas_m:
    num = one
    l = 0
    r = n
    if mas_n[n -1] >= num:
        if num < mas_n[0]:
            print(mas_n[0])
        else:
            while l < r:
                m = (l + r) //  2
                if mas_n[m] >= num:
                    r = m
                else:
                    l = m + 1
                
            print(mas_n[l] if (abs(mas_n[l] - num) < abs(mas_n[l - 1] - num)) else mas_n[l - 1])
    else:
        print(mas_n[n - 1])
# Out:
# 2 3
# 1 2000000000
# -2000000000 2000000000 0
# 1
# 2000000000
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
w, h, n = list(map(int, input().split()))
# Out:
# 2 3 10

# %%
w, h, n = list(map(int, input().split()))
l = 0
r = max(w, h) * n


while l < r:
    m = (l + r) // 2
    
    if (m // w) * (m // h) >= n:
        r = m
    else:
        l = m + 1
print(l)
# Out:
# 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, a, b, w, h = list(map(int, input().split()))

l1 = 0

r1 = max(w, h)

while l1 < r1:
    m = (l1 + r1 + 1) // 2
    
    if (w // (a + 2 * m)) * (h // (b + 2*m)) >= n:
        l1 = m
    else:
        r1 = m - 1
print(l1)    


l2 = 0
r2 = max(w, h)

while l2 < r2:
    m = (l2 + r2 + 1) // 2
    
    if (h // (a + 2 * m)) * (w // (b + 2*m)) >= n:
        l2 = m
    else:
        r2 = m - 1
print(l2)


print(max(l1, l2))
# Out:
# 18 1 7 98 49
# 4
# 5
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())
c = int(input())
# Out:
# 2
# 0
# 0

# %%
a = int(input())
b = int(input())
c = int(input())

l = 0 
r = (a + b) * 2


while l < r:
    m = (l + r) // 2
    #print(l, r, m)
    if ((a * 2 + b * 3 + c *4 + m *5) * 1.0 / (a + b + c + m)) >= 3.5:
        
        r = m
    else:
        l = m + 1
        
    #print(l, "l")
    
#print(((a * 2 + b * 3 + c *4 + (l) *5) * 1.000) / (a + b + c + l ))    

if (a + b + c) == 0:
    print(1)
else:
    print(l)
# Out:
# 100000000000000
# 100000000000000
# 100000000000000
# 100000000000001

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 5 1 2

# %%
n, x, y = list(map(int, input().split()))
if n == 1:
    print(min(x,y))
else:
    
    l = 0
    r = n * max(x, y)
    
    
    while l < r:
        m = (l + r) //2
        
        if (m // x) +(m // y) >= n - 1:
            r = m
        else:
            l = m + 1
            
    print(l+min(x,y))
# Out:
# 1 2 3
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, k = list(map(int, input().split()))
mas_n = [0] * n

for i in range(n):
    mas_n[i] = int(input())
# Out:
# 4 11
# 802
# 743
# 457
# 539

# %%
4 11
802
743
457
539

# %%
n, k = list(map(int, input().split()))
mas_n = [0] * n

for i in range(n):
    mas_n[i] = int(input())
    
def num(n1, k):
    return n1 // k

def check(mas, length):
    s = 0
    for one in mas:
        s += (one // length)
    return s
        
l = 1
r = max(mas_n)

while l < r:
    m = (l + r + 1) // 2
    if check(mas_n, m) >= k:
        l = m
    else:
        r = m - 1
if check(mas_n, 1) < k:
    print(0)
else:
    print(l)
# Out:
# 2 3
# 1
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)
