# %%
1 задача

# %%
troom, tcond = list(map(int, input().split()))
type_cond = input()


if type_cond =='auto':
    print(tcond)
elif type_cond == 'fan':
        print(troom)
elif type_cond == 'freeze':
    if troom > tcond:
        print(tcond)
    else:
        print(troom)
elif type_cond =='heat':
    if troom > tcond:
        print(troom)
    else:
        print(tcond)
# Out:
# 10 20
# freeze
# 10

# %% [markdown]
# 2 задача

# %%
a, b, c = tuple(map(int, input().split()))
if a >= b + c:
    print('NO')
elif b >= a + c:
    print('NO')
elif c >= a + b:
    print('NO')
else:
    print('YES')
# Out:
# 4 5 3
# YES

# %% [markdown]
# 3 задача

# %%
first = input()
second = input()
third = input()

number = input()
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_number = input()
first = input()
second = input()
third = input()
# Out:
# 8(495)430-23-97
# +7-4-9-5-43-023-97
# 4-3-0-2-3-9-7
# 8-495-430

# %%
def fun(num):
    l = 0
    
    for i in num:
        if i not in '-+()':
            l+=1
    return l

def compare(num1, num2):
    flag = 1
    if fun(num1) == fun(num2) and fun(num1) == 11:
        i = 0
        j = 0
        while k < len(num1):
# Out:
# 11

# %%
8(495)430-23-97
+7-4-9-5-43-023-97
4-3-0-2-3-9-7
8-495-430
# Out:
#   File "<ipython-input-1-12d313397fd6>", line 1
#     8(495)430-23-97
#             ^
# SyntaxError: invalid syntax

# %%
YES
YES
NO

# %%
def repl(word):
    letter ='()-+'
    for one in letter:
        word = word.replace(one,'')
    if len(word) < 11:
        word = '8495' + word
    return word


def compare(first, second):
    answer = 'YES'
    for i in range(1,len(first)):
        if first[i] != second[i]:
            answer ='NO'
            break
    return answer

first_new = repl(input())

first = repl(input())
second = repl(input())
third = repl(input())


answers = list()

for one in [first, second, third]:
    answers.append(compare(first_new,one))
for i in answers:
    print(i)
# Out:
# 8(495)430-23-97
# +7-4-9-5-43-023-97
# 4-3-0-2-3-9-7
# 8-495-430
# YES
# YES
# NO

# %%
8(495)430-23-97
+7-4-9-5-43-023-97
4-3-0-2-3-9-7
8-495-430

# %%
compare('84954302397','84354302397')
# Out:
# 'NO'

# %%
a = float(input())
b = float(input())
c = float(input())

if a == int(a) and b ==int(b) and c == int(c):
    if c < 0 :
        answer = 'NO SOLUTION'
    else:
        if a ==0:
            if b == c * c:
                answer ='MANY SOLUTIONS'
            else:
                answer ='NO SOLUTION'
        else:
            answer = (c*c -b) / a
            if answer >= -1*b / a and int(answer) == answer and a >= 0:
                answer = int(answer)
            elif answer <= -1*b / a and int(answer) == answer and a < 0:
                answer = int(answer)
            else:
                answer = 'NO SOLUTION'
else:
    answer = 'NO SOLUTION'
print(answer)
# Out:
# 0
# 0
# 0
# MANY SOLUTION

# %%
-2 == -2.0
# Out:
# True

# %%
8 == 8.0
# Out:
# True

# %%
-1 * 5
# Out:
# -5

# %%
print(6 == int(6.01))
# Out:
# True

# %%
a1, b1, a2, b2 = map(int, input().split())
# Out:
# 10 2 2 10

# %%
first = ((a1 + a2) * max(b1, b2), a1 + a2,max(b1, b2)) 
second = ((a1 + b2) * max(a2, b1), (a1 + b2),  max(a2, b1))
third = ((b1+b2) *max(a1, a2), (b1+b2), max(a1, a2))
thourth = ((b1+a2) *max(a1, b2), (b1+a2), max(a1, b2))

# %%
a1, b1, a2, b2 = map(int, input().split())

first = ((a1 + a2) * max(b1, b2), a1 + a2,max(b1, b2)) 
second = ((a1 + b2) * max(a2, b1), (a1 + b2),  max(a2, b1))
third = ((b1+b2) *max(a1, a2), (b1+b2), max(a1, a2))
thourth = ((b1+a2) *max(a1, b2), (b1+a2), max(a1, b2))

maxim = first[0]
result = first[1], first[2]
for one in [first, second, third, thourth]:
    if one[0] < maxim:
        maxim = one[0]
        result = one[1], one[2]

print(*result, sep=' ')
# Out:
# 40
# 20 2

# %%
thourth
# Out:
# (40, 4, 10)

# %%
n, k, m = map(int, input().split())
# Out:
# 10 5 2

# %%
#G


n, k, m = map(int, input().split())
# Out:
# 10 5 2

# %%
n, k, m = map(int, input().split())
details = 0


while n // k > 0:
    if m > k:
        break

    zagot = 0
    zagot = n // k
    
    n = n - (zagot) * k
    details = details + zagot*(k // m)
    n = n + (k - (k // m) * m) * zagot
    
print(details)
# Out:
# 30 5 7
# 0

# %%
a = int(input())
b = int(input())
 = int(input())
a = int(input())
a = int(input())
# Out:
#   File "<ipython-input-17-f6ee66874f8c>", line 1
#     a, b, c, d, e map(int, input().split())
#                     ^
# SyntaxError: invalid syntax

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
if (min(a,b) <= min(d,e) and max(a,b) <= max(d,e)) or (min(c,b) <= min(d,e) and max(c,b) <= max(d,e)) or (min(c,b) <= min(d,e) and max(a,c) <= max(d,e)):
    print('YES')
else:
    print('NO')
# Out:
# 2
# 2
# 2
# 1
# 1
# NO

# %%
a = int(input())
b = int(input())

n = int(input())
m = int(input())

first = n * a + n - 1
second = m*b + m - 1


if (first + a + 1) < second or (second + b+ 1) < first:
    print(-1)
else:
    print(min(first, second), max(first, second))
# Out:
# 1
# 2
# 7
# 11
# -1

# %%
1 2 7 11

# %%
a = int(input())
b = int(input())

n = int(input())
m = int(input())

first = n * a + n - 1
second = m*b + m - 1

if (first + a +1) > second and (second + b +1) > first:
    print(min(first, second), max(first, second))
else:
    print(-1)
# Out:
# 1
# 5
# 1
# 2
# 1 11

# %%
K1, M, K2, P2, N2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83f03c89ce32> in <module>
# ----> 1 K1, M, K2, P2, N2
#
# NameError: name 'K1' is not defined

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))
# Out:
# 11 1 1 1 1

# %%
if p2 > 1:
    x = k2 //((p2 -1) * m)
    
    p1 = k1 // (x * m)  if  ((k1 // (x * m)) == (k1 / (x * m))) else k1 // (x * m) + 1
    
    k1_0 = k1 - (p1 - 1) * x * m
    
    n1 = k1_0 // x if (k1_0 // x == k1_0/x) else k1_0 // x + 1
else:
    if n2 > 1:
        x0_min = k2 / n2
        x0_max = (k2 - 1) // (n2 - 1)

        if x0_max - x0_min > 1 or (( k2 / n2 == k2 // n2) and (x0_max - x0_min >=1)):
            p1 = -1
            n1 = -1
            
            
        else:
            p1 = k1 // (x0_max * m)  if  ((k1 // (x0_max * m)) == (k1 / (x0_max * m))) else k1 // (x0_max * m) + 1
            
            n1 = (k1 - (p1 - 1) * x0_max * m)
            
            n1 = n1 // x0_max if (n1 /  x0_max == n1 // x0_max) else n1 // x0_max + 1
    else:
        if 
print(p1, n1)
# Out:
# -1 -1

# %%
first  = input()
second  = input()


first_set = list()

for one in range(0, len(first) -1):
    first_set.append(first[one:one +2])




second_set = list()

for one in range(0, len(second) -1):
    second_set.append(second[one:one +2])

second_set = set(second_set)

res = 0
for one in first_set:
    if one in second_set:
        res += 1
print(res)
# Out:
# ABBACAB
# BCABB
# ['AB', 'BB', 'BA', 'AC', 'CA', 'AB']
# 4

# %%
ABBACAB
BCABB

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))
# Out:
# 89 20 41 1 11

# %%
if p2 > 1:
    a = k2 //((p2 - 1) * m)
elif n2 > 1 and p2 == 1:
    a_min = int(k2 / n2) if ((k2 / n2) == int(k2 / n2)) else (int(k2 / n2) + 1)
    a_max = int((k2 - 1) / (n2 - 1))
    
    if a_min == a_max:
        a = a_min
    else:
        a = 0
elif n2 == 1:
    a_min = k2
    a = 0
print(a_min, a, sep=' ')
# Out:
# 4
# 4
# 4 4

# %%
print(6)
# Out:
# 6

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))
# Out:
# 89 20 41 1 11

# %%
def validation(m, k2, p2, n2):
    if k2 < (p2 - 1) * m + n2:
        return -1
    
    a_max = k2 / ((p2 - 1) * m + (n2 -1))
    a_min = k2 / ((p2 - 1) * m + n2)
    
    a = a_min if a_min == int(a_min) else (int(a_min) + 1)
    
    if a > a_max:
        return -1
    
    return 0


if validation(m, k2, p2, n2) == -1:
    print(-1, -1)
elif p2 > 1:
    a = k2 // ((p2 - 1) * m)
    p1 = k1 //(m * a)
    n_0 = k1 - p1 * m * a      
    n1 = m if (n_0 / a == 0) else (n_0 / a if (n_0 // a == n_0 / a) else (n_0 // a + 1) )
    print(p1, n1)

elif p2 == 1 and n2 > 1:
    a_max = k2 / ((p2 - 1) * m + (n2 -1))
    a_min = k2 / ((p2 - 1) * m + n2)
    
    a_max = int(a_max)
    
    a_min = int(a_min) if (a_min == int(a_min)) else (int(a_min) + 1)
    
    a = a_min if a_min == a_max else -1
    
    if a == -1:
        print(0, 0)
# Out:
# -1

# %%
3 2 2 2 1

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
f = int(input())
# Out:
# 1
# 0
# 0
# 1
# 3
# 3

# %%
if a * d - c * b != 0:
    x_0 = (e * d - b * f) / (a * d - c *b)
    y_0 = (a * f - c * e) / (a * d - c *b)
    print(x_0, y_0) 
elif a == 0:
    
    if b != 0:
        y_0 = e / b
        if y_0 * d == f:
            print(4, y_0)
        else:
            print(5)
    else:
        if e == 0:
           
      
    
print(x_0, y_0)
# Out:
# 3.0 3.0

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
f = int(input())
# Out:
# 1
# 1
# 2
# 2
# 1
# 2

# %%
a = float(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
f = int(input())
if a == 0 and c != 0:
    a,c = c,a
    b, d = d, b
    e, f = f, e

    
if a != 0:
    d = d - (c * b / a)
    f = f - c * e / a
    c = 0


if d != 0:
    y_0 = f / d
    
    if a == 0:
        if y_0 * b == e:
            print(4, y_0)
        else:
            print(0)
    else:
        x_0 = e/ a - b *f / a/ d
        print(2, x_0, y_0)
elif d ==0:
    if f == 0:
        if b ==0:
            if a == 0:
                if e ==0:
                    print(5)
                else:
                    print(0)
            else:
                x_0 = e / a
                print(3, x_0)
        elif b!= 0:
            if a != 0:
                print(1, -a /b, e /b)
            else:
                print(4, e/b)
    elif d != 0:
        y_0 = f / d
        if a != 0:
            x_0 = e /a - b * f / a / d
            print(2, x_0, y_0)
        else:
            if y_0 * b == e:
                print(4, y_0)
            else:
                print(0)
    else:
        print(0)
# Out:
# 0
# 2
# 0
# 0
# 5
# 0
# 4 2.5

# %%
1
1
2
2
1
2

# %%
4 0.5
# Out:
# 6
# 4

# %%
a = int(input())
b = int(input())

n = int(input())
m = int(input())


first_min = n + (n - 1) * a if n > 0 else 0
first_max = n + (n + 1) * a if n > 0 else a

second_min = m +(m - 1) * b if m > 0 else 0
second_max = m +(m + 1) * b if m > 0 else b


if first_min > second_max or second_min > first_max or a < 0 or b < 0:
    print(-1)
else:
    print(min(first_min, second_min),min(first_max, second_max))
# Out:
# 0
# 0
# 0
# 0
# 0 0

# %%
1
5
1
2

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))
# Out:
# 89 20 41 1 11

# %%
a_min = k2/((p2 - 1) * m + n2)
a_max = k2 /((p2 - 1) * m + n2 -1)
print(a_min)
print(a_max)
# Out:
# 3.727272727272727
# 4.1

# %%
a_min1 = int(a_min) if a_min == int(a_min) else int(a_min) + 1
a_max1 = int(a_max) 

answer =99

if a_min1 >= a_max:
    answer = -1
elif len(range(a_min1, a_max1 +1)) > 1:
    answer = 0
    
if answer not in(0, 1):
    a = a_max1
    
p1 = k1 //(m * a) 
n1 = (k1 - (p1 * m * a)) 

p1 = p1 +1

n1 = n1 // a if (n1 // a) == (n1 / a) else (int(n1 /a) + 1)
print(p1, n1)
# Out:
# 2 3

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))


#print(a_min)
#print(a_max)
answer =99


if n2 == 1 and p2 == 1:
    if k1 <= k2:
        print(1 , 1)
    elif k1 <= m:
        print(3, 1)
    else:
        if m == 1:
            print(0, 1)
        else:
            print(0, 0)
else:
    a_min = k2/((p2 - 1) * m + n2)
    a_max = k2 /((p2 - 1) * m + n2 -1)
    a_min1 = int(a_min) if a_min == int(a_min) else int(a_min) + 1
    a_max1 = int(a_max) 
    
    #print(a_min)
    #print(a_max1)
    
    if a_min1 >= a_max or a_min < 1:
        answer = -1
    elif len(range(a_min1, a_max1 +1)) > 1:
        answer = 0
    
    if answer not in(0, -1):
        a = a_max1
    
        p1 = k1 //(m * a) 
        n1 = (k1 - (p1 * m * a)) 

        p1 = p1 +1

        n1 = n1 // a if (n1 // a) == (n1 / a) else (int(n1 /a) + 1)
    if answer not in (0, -1):
        print(p1, n1)
    elif answer == -1:
        print(-1, -1)
    else:
        print(0, 0)
# Out:
# 5 20 2 1 1
# 0 1

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))


#print(a_min)
#print(a_max)
answer =99
if k2 ==0 or p2 ==0 or n2 ==0 or m ==0 or n2> m:
    print(-1)

elif n2 == 1 and p2 == 1:
    if k1 <= k2:
        print(1 , 1)
    elif k1 <= m * k2:
        print(1, 0)
    else:
        if m == 1 and k2 > 0:
            print(0, 1)
        elif k2 ==0:
            print(-1, -1)
        else:
            print(0,  0)
else:
    a_min = k2/((p2 - 1) * m + n2)
    a_max = (k2 - 1) / ((p2 - 1) * m + n2 -1)
    
    a_min1 = int(a_min) if a_min == int(a_min) else int(a_min) + 1
    a_max1 = int(a_max) 
    
    
    
    if a_min1 > a_max or a_min < 1:
        answer = -1
        print(-1, -1)
    #elif len(range(a_min1, a_max1 +1)) > 1:
    else:
        answer = 0
        
        a_1 = a_min1
        a_2 = a_max1
        
       
        
        p1_first = k1 //(m * a_1) 
        p1_first = p1_first + 1 if (p1_first * m*a_1) < k1 else p1_first
        
        n1_first = (k1 - ((p1_first -1) * m * a_1)) if (p1_first * m *a_1) > k1 else m
        
        n1_first =m if n1_first == m else  (n1_first // a_1 if (n1_first // a_1) == (n1_first / a_1)\
                                            else (int(n1_first /a_1) + 1))
        
        
        
        p1_second = k1 //(m * a_2) 
        p1_second = p1_second + 1 if (p1_second * m*a_2) < k1 else p1_second
        
        n1_second = (k1 - ((p1_second -1) * m * a_2)) if (p1_first * m *a_2) > k1 else m
        
        n1_second =m if n1_second == m else  (n1_second // a_2 if (n1_second // a_2) == (n1_second / a_2)\
                                            else (int(n1_second /a_2) + 1))
        
        
        
        if p1_first == p1_second:
            print(p1_second, end =' ')
        else:
            print(0, end = ' ')
            
        if n1_first == n1_second:
            print(n1_second)
        else:
            print(0)
# Out:
# 10 3 50 1 50
# -1

# %%
k1, m, k2, p2, n2 = list(map(int, input().split()))

# %%
if p2 == 1 and n2 == 1:
    if k1 <= k2:
        p1 = p2
        n2 = n1
    else:

# %%
10 3 50 1 50
