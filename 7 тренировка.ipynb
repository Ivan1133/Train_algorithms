# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, m = list(map(int, input().split()))
lecturer = list()
for _ in range(m):
    start, end = list(map(int, input().split()))
    
    lecturer.append([start, -1])
    
    lecturer.append([end, 1])
sort_lecturer = sorted(lecturer)

last = 0
num = 0
s = 0

for place, type_ in sort_lecturer:
    
    if type_ == -1:
        num += 1
        if num == 1:
            first = place
        else:
            last = place
                
    else:
        num -= 1
        last = place
        if num == 0:
            s += (last + 1 - first)
print(n - s)
# Out:
# 10 2
# 1 1
# 1 2
# 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, m = list(map(int, input().split()))
place = list()
for _ in range(n):
    start, end = list(map(int, input().split()))
    
    place.append([start, -1])
    
    place.append([end, 1])
sort_place = sorted(place)
print(sort_place)

dots = list()
dots = list(map(int, input().split()))

print(dots)
# Out:
# 3 2
# 0 5
# -3 2
# 7 10
# [[-3, -1], [0, -1], [2, 1], [5, 1], [7, -1], [10, 1]]
# 1 6
# [1, 6]

# %%
3 2
0 5
-3 2
7 10
1 6

# %%
num = 0 
dot = 1
res = 0

for place, type_ in sort_lecturer:
    
    if type_ == -1:
        num += 1
        if num == 1:
            first = place
        else:
            first = place
                
    else:
        last = place
        if place>= first and place <= last:
            res = num
        num -= 1
        
        
print(res)
